# %%
def merge_sort(arr):
    if len(arr) <= 1:
        return arr
    mid = len(arr)//2
    left = arr[:mid]
    right = arr[mid:]
    left = merge_sort(left)
    right = merge_sort(right)
    return merge(left,right)

def merge(left,right):
    result = []
    i,j = 0,0
    while i < len(left) and j < len(right):
        if left[i] < right[j]:
            result.append(left[i]) 
            i+=1
        else:
            result.append(right[j])
            j+=1
    result+=left[i:]
    result+=right[j:]
    return result

user_input=input("Enter the list of numbers separated by spaces:")
arr=[int(num) for num in user_input.split()]
sorted_arr=merge_sort(arr)
print("Input Array:",arr)
print("Sorted Array:",sorted_arr)
# Out:
# Enter the list of numbers separated by spaces: 1 25 41 223 65 41 28 41
# Input Array: [1, 25, 41, 223, 65, 41, 28, 41]
# Sorted Array: [1, 25, 28, 41, 41, 41, 65, 223]
