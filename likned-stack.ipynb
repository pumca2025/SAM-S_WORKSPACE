# %%
class Node:
    def __init__(self,data):
        self.prev=None
        self.data=data
        self.next=None
class Dll:
    def __init__(self):
        self.head=None
        self.tail=None
    def addatStart(self,data):
        ele=Node(data)
        if(self.head==None):
            self.head=self.Node
            return
