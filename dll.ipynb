# %%
class Node:
    def __init__(self,data):
        self.data=data
        self.prev=None
        self.next=None
class Dll:
    def __init__(self):
        self.head=Node(None)
        self.tail=Node(None)
    def insertatStart(self,data):
        new=Node(data)
        if(self.head==None):
            self.head.data=new.data
            self.tail.data=new.data
        else:
            self.head.prev=new
            new.next=self.head
            self.head=new
    def insertAtEnd(self):
        new=Node(data)
        if(self.head==None):
            self.head.data=new.data
        else:
            
    def display(self):
        a=self.head
        while(a.next!=None):
            print(a.data)
            a=a.next
obj=Dll()
obj.insertatStart(10)
obj.insertatStart(20)
obj.insertatStart(5)
obj.display()
# Out:
# 5
# 20
# 10
